# %% [markdown]
# <a href="https://colab.research.google.com/github/zmomz/freq_strategies/blob/main/Binance_future_pairs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Valid **Binance** future USDT pairs
# ##  ... number of pairs: **275**

# %% [markdown]
# ['DGB/USDT:USDT',
#  'AMB/USDT:USDT',
#  'CAKE/USDT:USDT',
#  'RUNE/USDT:USDT',
#  'BB/USDT:USDT',
#  'XEM/USDT:USDT',
#  'XRP/USDT:USDT',
#  'SUSHI/USDT:USDT',
#  'BOND/USDT:USDT',
#  'TRX/USDT:USDT',
#  'AGLD/USDT:USDT',
#  'DUSK/USDT:USDT',
#  'DOT/USDT:USDT',
#  'FTM/USDT:USDT',
#  'STORJ/USDT:USDT',
#  'ONG/USDT:USDT',
#  'AXL/USDT:USDT',
#  'ZRO/USDT:USDT',
#  'GAS/USDT:USDT',
#  'LRC/USDT:USDT',
#  'UMA/USDT:USDT',
#  'MTL/USDT:USDT',
#  'SFP/USDT:USDT',
#  'SSV/USDT:USDT',
#  'EOS/USDT:USDT',
#  'IMX/USDT:USDT',
#  'BADGER/USDT:USDT',
#  'RSR/USDT:USDT',
#  'BIGTIME/USDT:USDT',
#  'ONDO/USDT:USDT',
#  'ATOM/USDT:USDT',
#  'GRT/USDT:USDT',
#  'API3/USDT:USDT',
#  'RONIN/USDT:USDT',
#  'MYRO/USDT:USDT',
#  'VANRY/USDT:USDT',
#  'FRONT/USDT:USDT',
#  'OGN/USDT:USDT',
#  'PHB/USDT:USDT',
#  'ORBS/USDT:USDT',
#  'USDC/USDT:USDT',
#  'SNT/USDT:USDT',
#  'DYDX/USDT:USDT',
#  'RIF/USDT:USDT',
#  'RAD/USDT:USDT',
#  'APE/USDT:USDT',
#  'XLM/USDT:USDT',
#  'DYM/USDT:USDT',
#  'OM/USDT:USDT',
#  'WAVES/USDT:USDT',
#  'MANA/USDT:USDT',
#  'COTI/USDT:USDT',
#  'ATA/USDT:USDT',
#  'AAVE/USDT:USDT',
#  'BTC/USDT:USDT',
#  'ADA/USDT:USDT',
#  'ICP/USDT:USDT',
#  'CKB/USDT:USDT',
#  'YGG/USDT:USDT',
#  'IOTX/USDT:USDT',
#  'ONE/USDT:USDT',
#  'JUP/USDT:USDT',
#  'ZEN/USDT:USDT',
#  'MAVIA/USDT:USDT',
#  'BEAMX/USDT:USDT',
#  'AI/USDT:USDT',
#  'ICX/USDT:USDT',
#  'OP/USDT:USDT',
#  'PORTAL/USDT:USDT',
#  'FLOW/USDT:USDT',
#  'ZETA/USDT:USDT',
#  'BCH/USDT:USDT',
#  'VET/USDT:USDT',
#  'NEO/USDT:USDT',
#  'SXP/USDT:USDT',
#  'STEEM/USDT:USDT',
#  'PERP/USDT:USDT',
#  'BSV/USDT:USDT',
#  'BAL/USDT:USDT',
#  'ANKR/USDT:USDT',
#  'WIF/USDT:USDT',
#  'AXS/USDT:USDT',
#  'TNSR/USDT:USDT',
#  'C98/USDT:USDT',
#  'LOOM/USDT:USDT',
#  'ETC/USDT:USDT',
#  'STMX/USDT:USDT',
#  'XAI/USDT:USDT',
#  'XVG/USDT:USDT',
#  'ZEC/USDT:USDT',
#  'BLZ/USDT:USDT',
#  'BAND/USDT:USDT',
#  'CVC/USDT:USDT',
#  'CTSI/USDT:USDT',
#  'NFP/USDT:USDT',
#  'SPELL/USDT:USDT',
#  'ILV/USDT:USDT',
#  'NMR/USDT:USDT',
#  'JOE/USDT:USDT',
#  'LDO/USDT:USDT',
#  'COMBO/USDT:USDT',
#  'CELO/USDT:USDT',
#  'LQTY/USDT:USDT',
#  'TWT/USDT:USDT',
#  'STRAX/USDT:USDT',
#  'NKN/USDT:USDT',
#  'HOT/USDT:USDT',
#  'CYBER/USDT:USDT',
#  'AGIX/USDT:USDT',
#  'ID/USDT:USDT',
#  'INJ/USDT:USDT',
#  'MATIC/USDT:USDT',
#  'HOOK/USDT:USDT',
#  'TOKEN/USDT:USDT',
#  'STRK/USDT:USDT',
#  'BEL/USDT:USDT',
#  'SC/USDT:USDT',
#  'TRB/USDT:USDT',
#  'SLP/USDT:USDT',
#  'SKL/USDT:USDT',
#  'LSK/USDT:USDT',
#  'ENA/USDT:USDT',
#  'NOT/USDT:USDT',
#  'CRV/USDT:USDT',
#  'LISTA/USDT:USDT',
#  'WOO/USDT:USDT',
#  'PEOPLE/USDT:USDT',
#  'IOTA/USDT:USDT',
#  'SOL/USDT:USDT',
#  'ORDI/USDT:USDT',
#  'MINA/USDT:USDT',
#  'CHR/USDT:USDT',
#  'MANTA/USDT:USDT',
#  'RNDR/USDT:USDT',
#  'WLD/USDT:USDT',
#  'POLYX/USDT:USDT',
#  'RDNT/USDT:USDT',
#  'IDEX/USDT:USDT',
#  'ZRX/USDT:USDT',
#  'BNX/USDT:USDT',
#  'ZK/USDT:USDT',
#  'TRU/USDT:USDT',
#  'PYTH/USDT:USDT',
#  'WAXP/USDT:USDT',
#  'METIS/USDT:USDT',
#  'AR/USDT:USDT',
#  'KAVA/USDT:USDT',
#  'LINK/USDT:USDT',
#  'LTC/USDT:USDT',
#  'SAND/USDT:USDT',
#  'LINA/USDT:USDT',
#  'MASK/USDT:USDT',
#  'EGLD/USDT:USDT',
#  'LUNA2/USDT:USDT',
#  'MDT/USDT:USDT',
#  'AUCTION/USDT:USDT',
#  'HIFI/USDT:USDT',
#  'UNI/USDT:USDT',
#  'ALICE/USDT:USDT',
#  'KAS/USDT:USDT',
#  'RVN/USDT:USDT',
#  'GALA/USDT:USDT',
#  'MEME/USDT:USDT',
#  'FLM/USDT:USDT',
#  'UNFI/USDT:USDT',
#  'ONT/USDT:USDT',
#  'STG/USDT:USDT',
#  'ACH/USDT:USDT',
#  'SUPER/USDT:USDT',
#  'THETA/USDT:USDT',
#  'OXT/USDT:USDT',
#  'DOGE/USDT:USDT',
#  'CHZ/USDT:USDT',
#  'BTCDOM/USDT:USDT',
#  'CTK/USDT:USDT',
#  'ALPHA/USDT:USDT',
#  'BTCST/USDT:USDT',
#  'STX/USDT:USDT',
#  'STPT/USDT:USDT',
#  'FET/USDT:USDT',
#  'TON/USDT:USDT',
#  'ENS/USDT:USDT',
#  'CELR/USDT:USDT',
#  'DENT/USDT:USDT',
#  'JASMY/USDT:USDT',
#  'MKR/USDT:USDT',
#  'LEVER/USDT:USDT',
#  'REEF/USDT:USDT',
#  'SEI/USDT:USDT',
#  'QNT/USDT:USDT',
#  'FIL/USDT:USDT',
#  'REN/USDT:USDT',
#  'GTC/USDT:USDT',
#  'BICO/USDT:USDT',
#  'PIXEL/USDT:USDT',
#  'RENDER/USDT:USDT',
#  'TURBO/USDT:USDT',
#  'KSM/USDT:USDT',
#  'KNC/USDT:USDT',
#  'BAKE/USDT:USDT',
#  'XVS/USDT:USDT',
#  'PENDLE/USDT:USDT',
#  'TAO/USDT:USDT',
#  'ETH/USDT:USDT',
#  'ARKM/USDT:USDT',
#  'FXS/USDT:USDT',
#  'MOVR/USDT:USDT',
#  'QTUM/USDT:USDT',
#  'SUI/USDT:USDT',
#  'ETHFI/USDT:USDT',
#  'XTZ/USDT:USDT',
#  'APT/USDT:USDT',
#  'MAGIC/USDT:USDT',
#  'ALGO/USDT:USDT',
#  'COMP/USDT:USDT',
#  'AEVO/USDT:USDT',
#  'MEW/USDT:USDT',
#  'NEAR/USDT:USDT',
#  'SNX/USDT:USDT',
#  'DAR/USDT:USDT',
#  'ARK/USDT:USDT',
#  'DEFI/USDT:USDT',
#  'ALT/USDT:USDT',
#  'BNB/USDT:USDT',
#  'ARPA/USDT:USDT',
#  'GAL/USDT:USDT',
#  'EDU/USDT:USDT',
#  'BNT/USDT:USDT',
#  'W/USDT:USDT',
#  'YFI/USDT:USDT',
#  'AVAX/USDT:USDT',
#  'LIT/USDT:USDT',
#  'GLMR/USDT:USDT',
#  'MAV/USDT:USDT',
#  'HBAR/USDT:USDT',
#  'XMR/USDT:USDT',
#  'DODOX/USDT:USDT',
#  'LPT/USDT:USDT',
#  'T/USDT:USDT',
#  'SAGA/USDT:USDT',
#  'ROSE/USDT:USDT',
#  'CVX/USDT:USDT',
#  'GMX/USDT:USDT',
#  'TLM/USDT:USDT',
#  'FTT/USDT:USDT',
#  'OMG/USDT:USDT',
#  'DASH/USDT:USDT',
#  'GLM/USDT:USDT',
#  'TIA/USDT:USDT',
#  'KLAY/USDT:USDT',
#  'IOST/USDT:USDT',
#  'OCEAN/USDT:USDT',
#  'USTC/USDT:USDT',
#  'BLUR/USDT:USDT',
#  'ENJ/USDT:USDT',
#  'OMNI/USDT:USDT',
#  'BAT/USDT:USDT',
#  'HIGH/USDT:USDT',
#  'BOME/USDT:USDT',
#  'RLC/USDT:USDT',
#  'NTRN/USDT:USDT',
#  'IO/USDT:USDT',
#  'ACE/USDT:USDT',
#  'ETHW/USDT:USDT',
#  'ASTR/USDT:USDT',
#  'POWR/USDT:USDT',
#  'RAY/USDT:USDT',
#  'KEY/USDT:USDT',
#  'JTO/USDT:USDT',
#  'REZ/USDT:USDT',
#  'GMT/USDT:USDT',
#  'CFX/USDT:USDT',
#  'ARB/USDT:USDT',
#  'HFT/USDT:USDT',
#  'ZIL/USDT:USDT']
